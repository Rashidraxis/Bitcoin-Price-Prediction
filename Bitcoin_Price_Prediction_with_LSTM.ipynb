# %%
import warnings
warnings.filterwarnings('ignore')
import os
import pandas as pd
import numpy as np
import math
import datetime as dt
import matplotlib.pyplot as plt

from sklearn.metrics import mean_squared_error, mean_absolute_error, explained_variance_score, r2_score 
from sklearn.metrics import mean_poisson_deviance, mean_gamma_deviance, accuracy_score
from sklearn.preprocessing import MinMaxScaler

from itertools import product
import statsmodels.api as sm

import tensorflow as tf

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.layers import LSTM

from itertools import cycle
import plotly.offline as py
import plotly.graph_objects as go
import plotly.express as px
from plotly.subplots import make_subplots

plt.style.use('seaborn-darkgrid')

# %%
root_path = "/major project/btc_23_feb.csv"
btc_input_df = pd.read_csv(root_path)
btc_input_df.tail()
# Out:
#                        time       low      high      open     close    volume
# 603650  2023-02-24 05:42:00  23902.35  23909.49  23902.35  23909.47  0.861892
# 603651  2023-02-24 05:43:00  23901.26  23909.47  23909.47  23905.26  0.796059
# 603652  2023-02-24 05:44:00  23901.01  23905.30  23905.26  23903.20  0.451450
# 603653  2023-02-24 05:45:00  23893.85  23905.06  23903.19  23897.22  1.657772
# 603654  2023-02-24 05:46:00  23895.14  23901.40  23897.20  23897.88  0.793310

# %%
btc_input_df.shape
# Out:
# (603655, 6)

# %%
btc_input_df.describe()
# Out:
#                  low           high           open          close  \
# count  603655.000000  603655.000000  603655.000000  603655.000000
# mean    27338.269401   27367.217001   27352.857297   27352.895648
# std      9822.911043    9834.358245    9828.697523    9828.665417
# min     15460.000000   15529.530000   15497.220000   15497.240000
# 25%     19527.790000   19547.000000   19537.465000   19537.445000
# 50%     22888.080000   22908.380000   22898.640000   22898.610000
# 75%     38338.980000   38384.335000   38361.730000   38361.855000
# max     48152.410000   48240.000000   48203.470000   48203.430000
#
#               volume
# count  603655.000000
# mean       15.531793
# std        22.695514
# min         0.046753
# 25%         4.292517
# 50%         8.983928
# 75%        18.256608
# max      1177.512807

# %%
btc_input_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 603655 entries, 0 to 603654
# Data columns (total 6 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   time    603655 non-null  object
#  1   low     603655 non-null  float64
#  2   high    603655 non-null  float64
#  3   open    603655 non-null  float64
#  4   close   603655 non-null  float64
#  5   volume  603655 non-null  float64
# dtypes: float64(5), object(1)
# memory usage: 27.6+ MB

# %%
btc_input_df_datetype = btc_input_df.astype({'time': 'datetime64'})

# %%
btc_input_df_datetype.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 603655 entries, 0 to 603654
# Data columns (total 6 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   time    603655 non-null  datetime64[ns]
#  1   low     603655 non-null  float64
#  2   high    603655 non-null  float64
#  3   open    603655 non-null  float64
#  4   close   603655 non-null  float64
#  5   volume  603655 non-null  float64
# dtypes: datetime64[ns](1), float64(5)
# memory usage: 27.6 MB

# %%
print('Null Values:',btc_input_df_datetype.isnull().values.sum())
print('If any NA values:', btc_input_df_datetype.isnull().values.any())
# Out:
# Null Values: 0
# If any NA values: False

# %%
btc_input_df_datetype.tail()
# Out:
#                       time       low      high      open     close    volume
# 603650 2023-02-24 05:42:00  23902.35  23909.49  23902.35  23909.47  0.861892
# 603651 2023-02-24 05:43:00  23901.26  23909.47  23909.47  23905.26  0.796059
# 603652 2023-02-24 05:44:00  23901.01  23905.30  23905.26  23903.20  0.451450
# 603653 2023-02-24 05:45:00  23893.85  23905.06  23903.19  23897.22  1.657772
# 603654 2023-02-24 05:46:00  23895.14  23901.40  23897.20  23897.88  0.793310

# %%
btc_input_df_datetype.head()
# Out:
#                  time       low      high      open     close     volume
# 0 2022-01-01 00:01:00  46228.00  46327.61  46244.63  46301.29  22.578581
# 1 2022-01-01 00:02:00  46284.81  46372.55  46305.44  46345.08  38.435608
# 2 2022-01-01 00:03:00  46299.97  46377.10  46345.08  46320.30   8.236354
# 3 2022-01-01 00:04:00  46285.70  46329.09  46316.24  46306.89  16.319029
# 4 2022-01-01 00:05:00  46268.25  46422.94  46315.10  46413.83  40.695435

# %%
btc_input_df_datetype.set_index("time").close.plot(figsize=(24,7), title="Bitcoin Weighted Price")
# Out:
# <AxesSubplot: title={'center': 'Bitcoin Weighted Price'}, xlabel='time'>

# %%
plt.figure(figsize=(15,12))
plt.suptitle('Lag Plots', fontsize=22)

plt.subplot(3,3,1)
pd.plotting.lag_plot(btc_input_df_datetype['close'], lag=1) #minute lag
plt.title('1-Minute Lag')

plt.subplot(3,3,2)
pd.plotting.lag_plot(btc_input_df_datetype['close'], lag=60) #hourley lag
plt.title('1-Hour Lag')

plt.subplot(3,3,3)
pd.plotting.lag_plot(btc_input_df_datetype['close'], lag=1440) #Daily lag
plt.title('Daily Lag')

plt.subplot(3,3,4)
pd.plotting.lag_plot(btc_input_df_datetype['close'], lag=10080) #weekly lag
plt.title('Weekly Lag')

plt.subplot(3,3,5)
pd.plotting.lag_plot(btc_input_df_datetype['close'], lag=43200) #month lag
plt.title('1-Month Lag')

plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
btc_input_df_datetype['date'] = pd.to_datetime(btc_input_df_datetype['time'],unit='s').dt.date

display(btc_input_df_datetype.head())

group = btc_input_df_datetype.groupby('date')

btc_closing_price_groupby_date = group['close'].mean()
# Out:
#                  time       low      high      open     close     volume  \
# 0 2022-01-01 00:01:00  46228.00  46327.61  46244.63  46301.29  22.578581
# 1 2022-01-01 00:02:00  46284.81  46372.55  46305.44  46345.08  38.435608
# 2 2022-01-01 00:03:00  46299.97  46377.10  46345.08  46320.30   8.236354
# 3 2022-01-01 00:04:00  46285.70  46329.09  46316.24  46306.89  16.319029
# 4 2022-01-01 00:05:00  46268.25  46422.94  46315.10  46413.83  40.695435
#
#          date
# 0  2022-01-01
# 1  2022-01-01
# 2  2022-01-01
# 3  2022-01-01
# 4  2022-01-01

# %%
display(btc_closing_price_groupby_date.head(10))

print("Length of btc_closing_price_groupby_date :", len(btc_closing_price_groupby_date))
# Out:
# date
# 2022-01-01    47123.818131
# 2022-01-02    47247.516278
# 2022-01-03    46820.535917
# 2022-01-04    46428.382424
# 2022-01-05    45897.798590
# 2022-01-06    43091.874514
# 2022-01-07    41992.719007
# 2022-01-08    41709.443056
# 2022-01-09    41907.349264
# 2022-01-10    41615.205056
# Name: close, dtype: float64
# Length of btc_closing_price_groupby_date : 420

# %% [markdown]
# # Train Test Split

# %%
prediction_days = 60

# Set Train data to be uplo ( Total data length - prediction_days )
df_train= btc_closing_price_groupby_date[:len(btc_closing_price_groupby_date)-prediction_days].values.reshape(-1,1)


# Set Test data to be the last prediction_days (or 60 days in this case)
df_test= btc_closing_price_groupby_date[len(btc_closing_price_groupby_date)-prediction_days:].values.reshape(-1,1)

# %%
df_test.shape
# Out:
# (60, 1)

# %%
chosen_col = 'Close'

fig, ax = plt.subplots(1, figsize=(13, 7))
ax.plot(df_train, label='Train', linewidth=2)
ax.plot(df_test, label='Test', linewidth=2)
ax.set_ylabel('Price USD', fontsize=14)
ax.set_title('', fontsize=16)
ax.legend(loc='best', fontsize=16)

# %%
scaler_train = MinMaxScaler(feature_range=(0, 1))
scaled_train = scaler_train.fit_transform(df_train)

scaler_test = MinMaxScaler(feature_range=(0, 1))
scaled_test = scaler_test.fit_transform(df_test)

# %%
def dataset_generator_lstm(dataset, look_back=5):
    # A “lookback period” defines the window-size of how many
    # previous timesteps are used in order to predict
    # the subsequent timestep. 
    dataX, dataY = [], []
    
    for i in range(len(dataset) - look_back):
        window_size_x = dataset[i:(i + look_back), 0]
        dataX.append(window_size_x)
        dataY.append(dataset[i + look_back, 0]) # this is the label or actual y-value
    return np.array(dataX), np.array(dataY)

trainX, trainY = dataset_generator_lstm(scaled_train)

testX, testY = dataset_generator_lstm(scaled_test)

print("trainX: ", trainX.shape)
print("trainY: ", trainY.shape)
print("testX: ", testX.shape)
print("testY: ", testY.shape)
# Out:
# trainX:  (355, 5)
# trainY:  (355,)
# testX:  (55, 5)
# testY:  (55,)

# %%
print("trainX: ", trainX)
# print("trainY: ", trainY)
# print("testY: ", testX)
# print("testY", testY)
# Out:
# trainX:  [[0.98601599 0.98992612 0.97642918 0.96403312 0.94726126]
#  [0.98992612 0.97642918 0.96403312 0.94726126 0.85856541]
#  [0.97642918 0.96403312 0.94726126 0.85856541 0.82382087]
#  ...
#  [0.023637   0.02715948 0.02837278 0.02674655 0.02830208]
#  [0.02715948 0.02837278 0.02674655 0.02830208 0.02839532]
#  [0.02837278 0.02674655 0.02830208 0.02839532 0.02796398]]

# %%
print(trainX.shape)
print(testX.shape)
# Out:
# (355, 5)
# (55, 5)

# %% [markdown]
# ### And now reshape trainX and testX

# %%
trainX = np.reshape(trainX, (trainX.shape[0], trainX.shape[1], 1))

testX = np.reshape(testX, (testX.shape[0], testX.shape[1], 1 ))

print("Shape of trainX: ", trainX.shape)
print("Shape of testX: ", testX.shape)
# Out:
# Shape of trainX:  (355, 5, 1)
# Shape of testX:  (55, 5, 1)

# %%
print("trainX: ", trainX)
print(" ********** ")
print("testX: ", testX)
# Out:
# trainX:  [[[0.98601599]
#   [0.98992612]
#   [0.97642918]
#   [0.96403312]
#   [0.94726126]]
#
#  [[0.98992612]
#   [0.97642918]
#   [0.96403312]
#   [0.94726126]
#   [0.85856541]]
#
#  [[0.97642918]
#   [0.96403312]
#   [0.94726126]
#   [0.85856541]
#   [0.82382087]]
#
#  ...
#
#  [[0.023637  ]
#   [0.02715948]
#   [0.02837278]
#   [0.02674655]
#   [0.02830208]]
#
#  [[0.02715948]
#   [0.02837278]
#   [0.02674655]
#   [0.02830208]
#   [0.02839532]]
#
#  [[0.02837278]
#   [0.02674655]
#   [0.02830208]
#   [0.02839532]
#   [0.02796398]]]
#  **********
# testX:  [[[0.03159908]
#   [0.01096924]
#   [0.00537844]
#   [0.        ]
#   [0.00232078]]
#
#  [[0.01096924]
#   [0.00537844]
#   [0.        ]
#   [0.00232078]
#   [0.00104055]]
#
#  [[0.00537844]
#   [0.        ]
#   [0.00232078]
#   [0.00104055]
#   [0.01748954]]
#
#  [[0.        ]
#   [0.00232078]
#   [0.00104055]
#   [0.01748954]
#   [0.01763282]]
#
#  [[0.00232078]
#   [0.00104055]
#   [0.01748954]
#   [0.01763282]
#   [0.03477404]]
#
#  [[0.00104055]
#   [0.01748954]
#   [0.01763282]
#   [0.03477404]
#   [0.03514825]]
#
#  [[0.01748954]
#   [0.01763282]
#   [0.03477404]
#   [0.03514825]
#   [0.03474858]]
#
#  [[0.01763282]
#   [0.03477404]
#   [0.03514825]
#   [0.03474858]
#   [0.04818412]]
#
#  [[0.03477404]
#   [0.03514825]
#   [0.03474858]
#   [0.04818412]
#   [0.04950223]]
#
#  [[0.03514825]
#   [0.03474858]
#   [0.04818412]
#   [0.04950223]
#   [0.08528941]]
#
#  [[0.03474858]
#   [0.04818412]
#   [0.04950223]
#   [0.08528941]
#   [0.09166451]]
#
#  [[0.04818412]
#   [0.04950223]
#   [0.08528941]
#   [0.09166451]
#   [0.11235728]]
#
#  [[0.04950223]
#   [0.08528941]
#   [0.09166451]
#   [0.11235728]
#   [0.22117529]]
#
#  [[0.08528941]
#   [0.09166451]
#   [0.11235728]
#   [0.22117529]
#   [0.31105238]]
#
#  [[0.09166451]
#   [0.11235728]
#   [0.22117529]
#   [0.31105238]
#   [0.52502901]]
#
#  [[0.11235728]
#   [0.22117529]
#   [0.31105238]
#   [0.52502901]
#   [0.52017191]]
#
#  [[0.22117529]
#   [0.31105238]
#   [0.52502901]
#   [0.52017191]
#   [0.55184897]]
#
#  [[0.31105238]
#   [0.52502901]
#   [0.52017191]
#   [0.55184897]
#   [0.57086731]]
#
#  [[0.52502901]
#   [0.52017191]
#   [0.55184897]
#   [0.57086731]
#   [0.56184645]]
#
#  [[0.52017191]
#   [0.55184897]
#   [0.57086731]
#   [0.56184645]
#   [0.52848817]]
#
#  [[0.55184897]
#   [0.57086731]
#   [0.56184645]
#   [0.52848817]
#   [0.58477057]]
#
#  [[0.57086731]
#   [0.56184645]
#   [0.52848817]
#   [0.58477057]
#   [0.77802831]]
#
#  [[0.56184645]
#   [0.52848817]
#   [0.58477057]
#   [0.77802831]
#   [0.76847827]]
#
#  [[0.52848817]
#   [0.58477057]
#   [0.77802831]
#   [0.76847827]
#   [0.77151051]]
#
#  [[0.58477057]
#   [0.77802831]
#   [0.76847827]
#   [0.77151051]
#   [0.78780495]]
#
#  [[0.77802831]
#   [0.76847827]
#   [0.77151051]
#   [0.78780495]
#   [0.75646171]]
#
#  [[0.76847827]
#   [0.77151051]
#   [0.78780495]
#   [0.75646171]
#   [0.80064096]]
#
#  [[0.77151051]
#   [0.78780495]
#   [0.75646171]
#   [0.80064096]
#   [0.79217405]]
#
#  [[0.78780495]
#   [0.75646171]
#   [0.80064096]
#   [0.79217405]
#   [0.79544444]]
#
#  [[0.75646171]
#   [0.80064096]
#   [0.79217405]
#   [0.79544444]
#   [0.84601741]]
#
#  [[0.80064096]
#   [0.79217405]
#   [0.79544444]
#   [0.84601741]
#   [0.82604   ]]
#
#  [[0.79217405]
#   [0.79544444]
#   [0.84601741]
#   [0.82604   ]
#   [0.7876987 ]]
#
#  [[0.79544444]
#   [0.84601741]
#   [0.82604   ]
#   [0.7876987 ]
#   [0.81266638]]
#
#  [[0.84601741]
#   [0.82604   ]
#   [0.7876987 ]
#   [0.81266638]
#   [0.89235907]]
#
#  [[0.82604   ]
#   [0.7876987 ]
#   [0.81266638]
#   [0.89235907]
#   [0.85069926]]
#
#  [[0.7876987 ]
#   [0.81266638]
#   [0.89235907]
#   [0.85069926]
#   [0.83992867]]
#
#  [[0.81266638]
#   [0.89235907]
#   [0.85069926]
#   [0.83992867]
#   [0.8162793 ]]
#
#  [[0.89235907]
#   [0.85069926]
#   [0.83992867]
#   [0.8162793 ]
#   [0.78074072]]
#
#  [[0.85069926]
#   [0.83992867]
#   [0.8162793 ]
#   [0.78074072]
#   [0.79030725]]
#
#  [[0.83992867]
#   [0.8162793 ]
#   [0.78074072]
#   [0.79030725]
#   [0.80417682]]
#
#  [[0.8162793 ]
#   [0.78074072]
#   [0.79030725]
#   [0.80417682]
#   [0.73484877]]
#
#  [[0.78074072]
#   [0.79030725]
#   [0.80417682]
#   [0.73484877]
#   [0.64196576]]
#
#  [[0.79030725]
#   [0.80417682]
#   [0.73484877]
#   [0.64196576]
#   [0.6329739 ]]
#
#  [[0.80417682]
#   [0.73484877]
#   [0.64196576]
#   [0.6329739 ]
#   [0.65285193]]
#
#  [[0.73484877]
#   [0.64196576]
#   [0.6329739 ]
#   [0.65285193]
#   [0.63196989]]
#
#  [[0.64196576]
#   [0.6329739 ]
#   [0.65285193]
#   [0.63196989]
#   [0.65860917]]
#
#  [[0.6329739 ]
#   [0.65285193]
#   [0.63196989]
#   [0.65860917]
#   [0.75588631]]
#
#  [[0.65285193]
#   [0.63196989]
#   [0.65860917]
#   [0.75588631]
#   [0.98993221]]
#
#  [[0.63196989]
#   [0.65860917]
#   [0.75588631]
#   [0.98993221]
#   [0.91702008]]
#
#  [[0.65860917]
#   [0.75588631]
#   [0.98993221]
#   [0.91702008]
#   [0.99033114]]
#
#  [[0.75588631]
#   [0.98993221]
#   [0.91702008]
#   [0.99033114]
#   [0.99374746]]
#
#  [[0.98993221]
#   [0.91702008]
#   [0.99033114]
#   [0.99374746]
#   [0.99608231]]
#
#  [[0.91702008]
#   [0.99033114]
#   [0.99374746]
#   [0.99608231]
#   [1.        ]]
#
#  [[0.99033114]
#   [0.99374746]
#   [0.99608231]
#   [1.        ]
#   [0.91686277]]
#
#  [[0.99374746]
#   [0.99608231]
#   [1.        ]
#   [0.91686277]
#   [0.9306397 ]]]

# %%
# checking the values for input_shape = (trainX.shape[1], trainX.shape[2])
# Note - `input_shape` of LSTM Model - `input_shape` is supposed to be (timesteps, n_features).

print("trainX.shape[1] - i.e. timesteps in input_shape = (timesteps, n_features) ", trainX.shape[1])
print("trainX.shape[2] - i.e. n_features in input_shape = (timesteps, n_features) ", trainX.shape[2])
# Out:
# trainX.shape[1] - i.e. timesteps in input_shape = (timesteps, n_features)  5
# trainX.shape[2] - i.e. n_features in input_shape = (timesteps, n_features)  1

# %%
regressor = Sequential()

regressor.add(LSTM(units = 128, activation = 'relu',return_sequences=True, input_shape = (trainX.shape[1], trainX.shape[2])))
regressor.add(Dropout(0.2))

regressor.add(LSTM(units = 64, input_shape = (trainX.shape[1], trainX.shape[2])))
regressor.add(Dropout(0.2))

regressor.add(Dense(units = 1))

regressor.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_2 (LSTM)               (None, 5, 128)            66560
#
#  dropout_2 (Dropout)         (None, 5, 128)            0
#
#  lstm_3 (LSTM)               (None, 64)                49408
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  dense_1 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 116,033
# Trainable params: 116,033
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

# Compiling the LSTM
regressor.compile(optimizer = 'adam', loss = 'mean_squared_error')

checkpoint_path = 'my_best_model.hdf5'

checkpoint = ModelCheckpoint(filepath=checkpoint_path, 
                             monitor='val_loss',
                             verbose=1, 
                             save_best_only=True,
                             mode='min')


earlystopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

callbacks = [checkpoint, earlystopping]
# callbacks = [checkpoint]


history = regressor.fit(trainX, trainY, batch_size = 32, epochs = 600, verbose=1, shuffle=False, validation_data=(testX, testY), callbacks=callbacks)
# Out:
# Epoch 1/600
# 10/12 [========================>.....] - ETA: 0s - loss: 0.2378
# Epoch 1: val_loss improved from inf to 0.18759, saving model to my_best_model.hdf5
# 12/12 [==============================] - 5s 99ms/step - loss: 0.2150 - val_loss: 0.1876
# Epoch 2/600
# 11/12 [==========================>...] - ETA: 0s - loss: 0.0820
# Epoch 2: val_loss improved from 0.18759 to 0.02460, saving model to my_best_model.hdf5
# 12/12 [==============================] - 0s 21ms/step - loss: 0.0818 - val_loss: 0.0246
# Epoch 3/600
# 10/12 [========================>.....] - ETA: 0s - loss: 0.0208
# Epoch 3: val_loss did not improve from 0.02460
# 12/12 [==============================] - 0s 16ms/step - loss: 0.0214 - val_loss: 0.0281
# Epoch 4/600
# 11/12 [==========================>...] - ETA: 0s - loss: 0.0117
# Epoch 4: val_loss improved from 0.02460 to 0.01879, saving model to my_best_model.hdf5
# 12/12 [==============================] - 0s 21ms/step - loss: 0.0117 - val_loss: 0.0188
# Epoch 5/600
# 11/12 [==========================>...] - ETA: 0s - loss: 0.0047
# Epoch 5: val_loss improved from 0.01879 to 0.01867, saving model to my_best_model.hdf5
# 12/12 [==============================] - 0s 22ms/step - loss: 0.0047 - val_loss: 0.0187
# Epoch 6/600
# 11/12 [==========================>...] - ETA: 0s - loss: 0.0060
# Epoch 6: val_loss did not improve from 0.01867
# 12/12 [==============================] - 0s 17ms/step - loss: 0.0059 - val_loss: 0.0241
# Epoch 7/600
# 11/12 [==========================>...] - ETA: 0s - loss: 0.0061
# Epoch 7: val_loss improved from 0.01867 to 0.01642, saving model to my_best_model.hdf5
# 12/12 [==============================] - 0s 21ms/step - loss: 0.0060 - val_loss: 0.0164
# Epoch 8/600
# 11/12 [==========================>...] - ETA: 0s - loss: 0.0056
# Epoch 8: val_loss did not improve from 0.01642
# 12/12 [==============================] - 0s 15ms/step - loss: 0.0056 - val_loss: 0.0339
# Epoch 9/600
# 12/12 [==============================] - ETA: 0s - loss: 0.0075
# Epoch 9: val_loss did not improve from 0.01642
# 12/12 [==============================] - 0s 16ms/step - loss: 0.0075 - val_loss: 0.0273
# Epoch 10/600
# 11/12 [==========================>...] - ETA: 0s - loss: 0.0122
# Epoch 10: val_loss did not improve from 0.01642
# 12/12 [==============================] - 0s 16ms/step - loss: 0.0121 - val_loss: 0.0816
# Epoch 11/600
# 11/12 [==========================>...] - ETA: 0s - loss: 0.0260
# Epoch 11: val_loss did not improve from 0.01642
# 12/12 [==============================] - 0s 16ms/step - loss: 0.0258 - val_loss: 0.0257
# Epoch 12/600
# 11/12 [==========================>...] - ETA: 0s - loss: 0.0118
# Epoch 12: val_loss did not improve from 0.01642
# 12/12 [==============================] - 0s 16ms/step - loss: 0.0117 - val_loss: 0.0749
# Epoch 13/600
# 11/12 [==========================>...] - ETA: 0s - loss: 0.0242
# Epoch 13: val_loss improved from 0.01642 to 0.01536, saving model to my_best_model.hdf5
# 12/12 [==============================] - 0s 21ms/step - loss: 0.0240 - val_loss: 0.0154
# Epoch 14/600
#  9/12 [=====================>........] - ETA: 0s - loss: 0.0097
# Epoch 14: val_loss did not improve from 0.01536
# 12/12 [==============================] - 0s 16ms/step - loss: 0.0081 - val_loss: 0.0421
# Epoch 15/600
# 11/12 [==========================>...] - ETA: 0s - loss: 0.0114
# Epoch 15: val_loss improved from 0.01536 to 0.01502, saving model to my_best_model.hdf5
# 12/12 [==============================] - 0s 21ms/step - loss: 0.0114 - val_loss: 0.0150
# Epoch 16/600
# 11/12 [==========================>...] - ETA: 0s - loss: 0.0059
# Epoch 16: val_loss did not improve from 0.01502
# 12/12 [==============================] - 0s 16ms/step - loss: 0.0059 - val_loss: 0.0273
# Epoch 17/600
# 11/12 [==========================>...] - ETA: 0s - loss: 0.0064
# Epoch 17: val_loss improved from 0.01502 to 0.01488, saving model to my_best_model.hdf5
# 12/12 [==============================] - 0s 21ms/step - loss: 0.0064 - val_loss: 0.0149
# Epoch 18/600
# 10/12 [========================>.....] - ETA: 0s - loss: 0.0060
# Epoch 18: val_loss did not improve from 0.01488
# 12/12 [==============================] - 0s 17ms/step - loss: 0.0054 - val_loss: 0.0267
# Epoch 19/600
# 10/12 [========================>.....] - ETA: 0s - loss: 0.0074
# Epoch 19: val_loss did not improve from 0.01488
# 12/12 [==============================] - 0s 17ms/step - loss: 0.0067 - val_loss: 0.0149
# Epoch 20/600
# 10/12 [========================>.....] - ETA: 0s - loss: 0.0064
# Epoch 20: val_loss did not improve from 0.01488
# 12/12 [==============================] - 0s 16ms/step - loss: 0.0058 - val_loss: 0.0280
# Epoch 21/600
# 11/12 [==========================>...] - ETA: 0s - loss: 0.0067
# Epoch 21: val_loss improved from 0.01488 to 0.01476, saving model to my_best_model.hdf5
# 12/12 [==============================] - 0s 20ms/step - loss: 0.0067 - val_loss: 0.0148
# Epoch 22/600
# 11/12 [==========================>...] - ETA: 0s - loss: 0.0053
# Epoch 22: val_loss did not improve from 0.01476
# 12/12 [==============================] - 0s 16ms/step - loss: 0.0053 - val_loss: 0.0303
# Epoch 23/600
# 11/12 [==========================>...] - ETA: 0s - loss: 0.0065
# Epoch 23: val_loss did not improve from 0.01476
# 12/12 [==============================] - 0s 15ms/step - loss: 0.0065 - val_loss: 0.0150
# Epoch 24/600
# 10/12 [========================>.....] - ETA: 0s - loss: 0.0069
# Epoch 24: val_loss did not improve from 0.01476
# 12/12 [==============================] - 0s 20ms/step - loss: 0.0062 - val_loss: 0.0351
# Epoch 25/600
#  9/12 [=====================>........] - ETA: 0s - loss: 0.0101
# Epoch 25: val_loss did not improve from 0.01476
# 12/12 [==============================] - 0s 18ms/step - loss: 0.0086 - val_loss: 0.0151
# Epoch 26/600
#  9/12 [=====================>........] - ETA: 0s - loss: 0.0079
# Epoch 26: val_loss did not improve from 0.01476
# 12/12 [==============================] - 0s 18ms/step - loss: 0.0066 - val_loss: 0.0353
# Epoch 27/600
#  9/12 [=====================>........] - ETA: 0s - loss: 0.0099
# Epoch 27: val_loss improved from 0.01476 to 0.01475, saving model to my_best_model.hdf5
# 12/12 [==============================] - 0s 25ms/step - loss: 0.0083 - val_loss: 0.0147
# Epoch 28/600
#  9/12 [=====================>........] - ETA: 0s - loss: 0.0080
# Epoch 28: val_loss did not improve from 0.01475
# 12/12 [==============================] - 0s 18ms/step - loss: 0.0067 - val_loss: 0.0369
# Epoch 29/600
# 11/12 [==========================>...] - ETA: 0s - loss: 0.0092
# Epoch 29: val_loss did not improve from 0.01475
# 12/12 [==============================] - 0s 16ms/step - loss: 0.0091 - val_loss: 0.0151
# Epoch 30/600
# 10/12 [========================>.....] - ETA: 0s - loss: 0.0075
# Epoch 30: val_loss did not improve from 0.01475
# 12/12 [==============================] - 0s 18ms/step - loss: 0.0068 - val_loss: 0.0403
# Epoch 31/600
# 11/12 [==========================>...] - ETA: 0s - loss: 0.0099
# Epoch 31: val_loss did not improve from 0.01475
# 12/12 [==============================] - 0s 17ms/step - loss: 0.0099 - val_loss: 0.0160
# Epoch 32/600
# 11/12 [==========================>...] - ETA: 0s - loss: 0.0081
# Epoch 32: val_loss did not improve from 0.01475
# 12/12 [==============================] - 0s 16ms/step - loss: 0.0080 - val_loss: 0.0456
# Epoch 33/600
# 11/12 [==========================>...] - ETA: 0s - loss: 0.0128
# Epoch 33: val_loss did not improve from 0.01475
# 12/12 [==============================] - 0s 17ms/step - loss: 0.0128 - val_loss: 0.0149
# Epoch 34/600
# 10/12 [========================>.....] - ETA: 0s - loss: 0.0082
# Epoch 34: val_loss did not improve from 0.01475
# 12/12 [==============================] - 0s 17ms/step - loss: 0.0074 - val_loss: 0.0388
# Epoch 35/600
#  9/12 [=====================>........] - ETA: 0s - loss: 0.0107
# Epoch 35: val_loss improved from 0.01475 to 0.01362, saving model to my_best_model.hdf5
# 12/12 [==============================] - 0s 25ms/step - loss: 0.0089 - val_loss: 0.0136
# Epoch 36/600
# 11/12 [==========================>...] - ETA: 0s - loss: 0.0059
# Epoch 36: val_loss did not improve from 0.01362
# 12/12 [==============================] - 0s 17ms/step - loss: 0.0058 - val_loss: 0.0320
# Epoch 37/600
# 10/12 [========================>.....] - ETA: 0s - loss: 0.0086
# Epoch 37: val_loss did not improve from 0.01362
# 12/12 [==============================] - 0s 18ms/step - loss: 0.0078 - val_loss: 0.0138
# Epoch 38/600
# 10/12 [========================>.....] - ETA: 0s - loss: 0.0066
# Epoch 38: val_loss did not improve from 0.01362
# 12/12 [==============================] - 0s 18ms/step - loss: 0.0060 - val_loss: 0.0294
# Epoch 39/600
# 10/12 [========================>.....] - ETA: 0s - loss: 0.0070
# Epoch 39: val_loss improved from 0.01362 to 0.01348, saving model to my_best_model.hdf5
# 12/12 [==============================] - 0s 23ms/step - loss: 0.0064 - val_loss: 0.0135
# Epoch 40/600
# 10/12 [========================>.....] - ETA: 0s - loss: 0.0054
# Epoch 40: val_loss did not improve from 0.01348
# 12/12 [==============================] - 0s 18ms/step - loss: 0.0049 - val_loss: 0.0283
# Epoch 41/600
# 11/12 [==========================>...] - ETA: 0s - loss: 0.0073
# Epoch 41: val_loss did not improve from 0.01348
# 12/12 [==============================] - 0s 17ms/step - loss: 0.0072 - val_loss: 0.0136
# Epoch 42/600
#  9/12 [=====================>........] - ETA: 0s - loss: 0.0075
# Epoch 42: val_loss did not improve from 0.01348
# 12/12 [==============================] - 0s 19ms/step - loss: 0.0063 - val_loss: 0.0294
# Epoch 43/600
# 11/12 [==========================>...] - ETA: 0s - loss: 0.0080
# Epoch 43: val_loss improved from 0.01348 to 0.01345, saving model to my_best_model.hdf5
# 12/12 [==============================] - 0s 23ms/step - loss: 0.0079 - val_loss: 0.0134
# Epoch 44/600
# 10/12 [========================>.....] - ETA: 0s - loss: 0.0068
# Epoch 44: val_loss did not improve from 0.01345
# 12/12 [==============================] - 0s 17ms/step - loss: 0.0061 - val_loss: 0.0319
# Epoch 45/600
# 10/12 [========================>.....] - ETA: 0s - loss: 0.0082
# Epoch 45: val_loss did not improve from 0.01345
# 12/12 [==============================] - 0s 17ms/step - loss: 0.0075 - val_loss: 0.0135
# Epoch 46/600
# 10/12 [========================>.....] - ETA: 0s - loss: 0.0069
# Epoch 46: val_loss did not improve from 0.01345
# 12/12 [==============================] - 0s 18ms/step - loss: 0.0063 - val_loss: 0.0345
# Epoch 47/600
# 11/12 [==========================>...] - ETA: 0s - loss: 0.0086
# Epoch 47: val_loss did not improve from 0.01345
# 12/12 [==============================] - 0s 18ms/step - loss: 0.0085 - val_loss: 0.0136
# Epoch 48/600
#  9/12 [=====================>........] - ETA: 0s - loss: 0.0076
# Epoch 48: val_loss did not improve from 0.01345
# 12/12 [==============================] - 0s 19ms/step - loss: 0.0063 - val_loss: 0.0318
# Epoch 49/600
# 11/12 [==========================>...] - ETA: 0s - loss: 0.0079
# Epoch 49: val_loss did not improve from 0.01345
# 12/12 [==============================] - 0s 17ms/step - loss: 0.0078 - val_loss: 0.0137
# Epoch 50/600
# 10/12 [========================>.....] - ETA: 0s - loss: 0.0057
# Epoch 50: val_loss did not improve from 0.01345
# 12/12 [==============================] - 0s 18ms/step - loss: 0.0052 - val_loss: 0.0278
# Epoch 51/600
#  9/12 [=====================>........] - ETA: 0s - loss: 0.0082
# Epoch 51: val_loss improved from 0.01345 to 0.01303, saving model to my_best_model.hdf5
# 12/12 [==============================] - 0s 23ms/step - loss: 0.0069 - val_loss: 0.0130
# Epoch 52/600
# 11/12 [==========================>...] - ETA: 0s - loss: 0.0052
# Epoch 52: val_loss did not improve from 0.01303
# 12/12 [==============================] - 0s 18ms/step - loss: 0.0052 - val_loss: 0.0271
# Epoch 53/600
#  8/12 [===================>..........] - ETA: 0s - loss: 0.0083
# Epoch 53: val_loss did not improve from 0.01303
# 12/12 [==============================] - 0s 19ms/step - loss: 0.0063 - val_loss: 0.0130
# Epoch 54/600
# 10/12 [========================>.....] - ETA: 0s - loss: 0.0054
# Epoch 54: val_loss did not improve from 0.01303
# 12/12 [==============================] - 0s 17ms/step - loss: 0.0049 - val_loss: 0.0249
# Epoch 55/600
# 10/12 [========================>.....] - ETA: 0s - loss: 0.0059
# Epoch 55: val_loss improved from 0.01303 to 0.01282, saving model to my_best_model.hdf5
# 12/12 [==============================] - 0s 24ms/step - loss: 0.0054 - val_loss: 0.0128
# Epoch 56/600
# 10/12 [========================>.....] - ETA: 0s - loss: 0.0050
# Epoch 56: val_loss did not improve from 0.01282
# 12/12 [==============================] - 0s 18ms/step - loss: 0.0045 - val_loss: 0.0269
# Epoch 57/600
#  9/12 [=====================>........] - ETA: 0s - loss: 0.0069
# Epoch 57: val_loss did not improve from 0.01282
# 12/12 [==============================] - 0s 18ms/step - loss: 0.0059 - val_loss: 0.0129
# Epoch 58/600
# 10/12 [========================>.....] - ETA: 0s - loss: 0.0056
# Epoch 58: val_loss did not improve from 0.01282
# 12/12 [==============================] - 0s 18ms/step - loss: 0.0051 - val_loss: 0.0262
# Epoch 59/600
#  9/12 [=====================>........] - ETA: 0s - loss: 0.0069
# Epoch 59: val_loss did not improve from 0.01282
# 12/12 [==============================] - 0s 19ms/step - loss: 0.0059 - val_loss: 0.0131
# Epoch 60/600
#  9/12 [=====================>........] - ETA: 0s - loss: 0.0061
# Epoch 60: val_loss did not improve from 0.01282
# 12/12 [==============================] - 0s 18ms/step - loss: 0.0052 - val_loss: 0.0244
# Epoch 61/600
#  9/12 [=====================>........] - ETA: 0s - loss: 0.0062
# Epoch 61: val_loss improved from 0.01282 to 0.01278, saving model to my_best_model.hdf5
# 12/12 [==============================] - 0s 26ms/step - loss: 0.0052 - val_loss: 0.0128
# Epoch 62/600
# 11/12 [==========================>...] - ETA: 0s - loss: 0.0042
# Epoch 62: val_loss did not improve from 0.01278
# 12/12 [==============================] - 0s 17ms/step - loss: 0.0042 - val_loss: 0.0226
# Epoch 63/600
# 10/12 [========================>.....] - ETA: 0s - loss: 0.0054
# Epoch 63: val_loss did not improve from 0.01278
# 12/12 [==============================] - 0s 17ms/step - loss: 0.0049 - val_loss: 0.0129
# Epoch 64/600
#  9/12 [=====================>........] - ETA: 0s - loss: 0.0049
# Epoch 64: val_loss did not improve from 0.01278
# 12/12 [==============================] - 0s 18ms/step - loss: 0.0042 - val_loss: 0.0240
# Epoch 65/600
#  9/12 [=====================>........] - ETA: 0s - loss: 0.0064
# Epoch 65: val_loss improved from 0.01278 to 0.01270, saving model to my_best_model.hdf5
# 12/12 [==============================] - 0s 26ms/step - loss: 0.0055 - val_loss: 0.0127
# Epoch 66/600
# 10/12 [========================>.....] - ETA: 0s - loss: 0.0052
# Epoch 66: val_loss did not improve from 0.01270
# 12/12 [==============================] - 0s 18ms/step - loss: 0.0047 - val_loss: 0.0251
# Epoch 67/600
#  9/12 [=====================>........] - ETA: 0s - loss: 0.0060
# Epoch 67: val_loss did not improve from 0.01270
# 12/12 [==============================] - 0s 18ms/step - loss: 0.0052 - val_loss: 0.0128
# Epoch 68/600
# 10/12 [========================>.....] - ETA: 0s - loss: 0.0054
# Epoch 68: val_loss did not improve from 0.01270
# 12/12 [==============================] - 0s 18ms/step - loss: 0.0049 - val_loss: 0.0257
# Epoch 69/600
# 10/12 [========================>.....] - ETA: 0s - loss: 0.0065
# Epoch 69: val_loss did not improve from 0.01270
# 12/12 [==============================] - 0s 17ms/step - loss: 0.0059 - val_loss: 0.0130
# Epoch 70/600
# 10/12 [========================>.....] - ETA: 0s - loss: 0.0057
# Epoch 70: val_loss did not improve from 0.01270
# 12/12 [==============================] - 0s 18ms/step - loss: 0.0052 - val_loss: 0.0307
# Epoch 71/600
# 10/12 [========================>.....] - ETA: 0s - loss: 0.0073
# Epoch 71: val_loss did not improve from 0.01270
# 12/12 [==============================] - 0s 17ms/step - loss: 0.0067 - val_loss: 0.0129
# Epoch 72/600
#  9/12 [=====================>........] - ETA: 0s - loss: 0.0068
# Epoch 72: val_loss did not improve from 0.01270
# 12/12 [==============================] - 0s 17ms/step - loss: 0.0057 - val_loss: 0.0309
# Epoch 73/600
# 10/12 [========================>.....] - ETA: 0s - loss: 0.0078
# Epoch 73: val_loss did not improve from 0.01270
# 12/12 [==============================] - 0s 18ms/step - loss: 0.0072 - val_loss: 0.0127
# Epoch 74/600
#  9/12 [=====================>........] - ETA: 0s - loss: 0.0068
# Epoch 74: val_loss did not improve from 0.01270
# 12/12 [==============================] - 0s 18ms/step - loss: 0.0057 - val_loss: 0.0315
# Epoch 75/600
# 10/12 [========================>.....] - ETA: 0s - loss: 0.0086
# Epoch 75: val_loss did not improve from 0.01270
# 12/12 [==============================] - 0s 18ms/step - loss: 0.0079 - val_loss: 0.0131

# %%
from tensorflow.keras.models import load_model

model_from_saved_checkpoint = load_model(checkpoint_path)

# %%
plt.figure(figsize=(16,7))
plt.plot(history.history['loss'], label='train')

plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()

# %%
# Transformation to original form and making the predictions

# predicted_btc_price_test_data = regressor.predict(testX)
predicted_btc_price_test_data = model_from_saved_checkpoint.predict(testX)

predicted_btc_price_test_data = scaler_test.inverse_transform(predicted_btc_price_test_data.reshape(-1, 1))

test_actual = scaler_test.inverse_transform(testY.reshape(-1, 1))
# Out:
# 2/2 [==============================] - 1s 11ms/step

# %%
plt.figure(figsize=(16,7))

plt.plot(predicted_btc_price_test_data, 'r', marker='.', label='Predicted Test')

plt.plot(test_actual, marker='.', label='Actual Test')

plt.legend()
plt.show()

# %%
# Transformation to original form and making the predictions

predicted_btc_price_train_data = model_from_saved_checkpoint.predict(trainX)

predicted_btc_price_train_data = scaler_train.inverse_transform(predicted_btc_price_train_data.reshape(-1, 1))

train_actual = scaler_train.inverse_transform(trainY.reshape(-1, 1))
# Out:
# 12/12 [==============================] - 0s 4ms/step

# %%
plt.figure(figsize=(16,7))

plt.plot(predicted_btc_price_train_data, 'r', marker='.', label='Predicted Train')

plt.plot(train_actual, marker='.', label='Actual Train')

plt.legend()
plt.show()

# %%
rmse_lstm_test = math.sqrt(mean_squared_error(test_actual, predicted_btc_price_test_data))

print('Test RMSE: %.3f' % rmse_lstm_test)

# With 2 Layers + Dropout + lookback=5 => I got - Test RMSE: 1666.162  => This seems best
# Out:
# Test RMSE: 919.176

# %%
rmse_lstm_train = math.sqrt(mean_squared_error(train_actual, predicted_btc_price_train_data))

print('Test RMSE: %.3f' % rmse_lstm_train)

# With 2 Layers + Dropout + lookback=5 => I got - Test RMSE: 1047.916  => This seems best
# Out:
# Test RMSE: 2014.714

# %%
testX
testX.shape
# Out:
# (55, 5, 1)

# %%
lookback_period = 5

# That is the original Trading data ended on 30-Oct-2021, but going to forecast for Future 5 days beyond 30-Oct-2021

testX_last_5_days = testX[testX.shape[0] - lookback_period :  ]

testX_last_5_days.shape
# Out:
# (5, 5, 1)

# %%
testX_last_5_days
# Out:
# array([[[0.75588631],
#         [0.98993221],
#         [0.91702008],
#         [0.99033114],
#         [0.99374746]],
#
#        [[0.98993221],
#         [0.91702008],
#         [0.99033114],
#         [0.99374746],
#         [0.99608231]],
#
#        [[0.91702008],
#         [0.99033114],
#         [0.99374746],
#         [0.99608231],
#         [1.        ]],
#
#        [[0.99033114],
#         [0.99374746],
#         [0.99608231],
#         [1.        ],
#         [0.91686277]],
#
#        [[0.99374746],
#         [0.99608231],
#         [1.        ],
#         [0.91686277],
#         [0.9306397 ]]])

# %%
predicted_5_days_forecast_price_test_x = []

for i in range(5):  
  predicted_forecast_price_test_x = model_from_saved_checkpoint.predict(testX_last_5_days[i:i+1])
  
  predicted_forecast_price_test_x = scaler_test.inverse_transform(predicted_forecast_price_test_x.reshape(-1, 1))
  # print(predicted_forecast_price_test_x)
  predicted_5_days_forecast_price_test_x.append(predicted_forecast_price_test_x)
  
print("Forecast for the next 5 Days Beyond the actual trading days ", np.array(predicted_5_days_forecast_price_test_x)) 
# That is the original Trading data ended on 30-Oct-2021, but now I am going to forecast beyond 30-Oct-2021
# Out:
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# Forecast for the next 5 Days Beyond the actual trading days  [[[24299.947]]
#
#  [[24680.922]]
#
#  [[24689.537]]
#
#  [[24714.447]]
#
#  [[24652.297]]]

# %%
predicted_5_days_forecast_price_test_x = np.array(predicted_5_days_forecast_price_test_x)

predicted_5_days_forecast_price_test_x.shape
# Out:
# (5, 1, 1)

# %%
predicted_btc_price_test_data.shape
# Out:
# (55, 1)

# %%
predicted_btc_price_test_data
# Out:
# array([[16850.049],
#        [16818.264],
#        [16818.17 ],
#        [16827.242],
#        [16853.506],
#        [16883.203],
#        [16917.793],
#        [16950.006],
#        [16990.312],
#        [17053.871],
#        [17146.96 ],
#        [17271.934],
#        [17502.38 ],
#        [17879.75 ],
#        [18491.93 ],
#        [19281.494],
#        [20168.787],
#        [20907.516],
#        [21426.87 ],
#        [21452.018],
#        [21552.697],
#        [21822.172],
#        [22137.38 ],
#        [22495.89 ],
#        [22946.322],
#        [23241.441],
#        [23275.748],
#        [23303.059],
#        [23338.436],
#        [23415.441],
#        [23511.023],
#        [23500.688],
#        [23548.732],
#        [23678.719],
#        [23655.016],
#        [23684.85 ],
#        [23751.088],
#        [23726.04 ],
#        [23574.322],
#        [23503.287],
#        [23340.271],
#        [23090.854],
#        [22843.78 ],
#        [22649.373],
#        [22396.23 ],
#        [22263.97 ],
#        [22425.504],
#        [22804.844],
#        [23212.488],
#        [23764.957],
#        [24299.947],
#        [24680.924],
#        [24689.537],
#        [24714.447],
#        [24652.297]], dtype=float32)

# %%
predicted_5_days_forecast_price_test_x
# Out:
# array([[[24299.947]],
#
#        [[24680.922]],
#
#        [[24689.537]],
#
#        [[24714.447]],
#
#        [[24652.297]]], dtype=float32)

# %%
predicted_5_days_forecast_price_test_x = predicted_5_days_forecast_price_test_x.flatten()

predicted_5_days_forecast_price_test_x
# Out:
# array([24299.947, 24680.922, 24689.537, 24714.447, 24652.297],
#       dtype=float32)

# %%
predicted_btc_price_test_data = predicted_btc_price_test_data.flatten()

predicted_btc_price_test_data
# Out:
# array([16850.049, 16818.264, 16818.17 , 16827.242, 16853.506, 16883.203,
#        16917.793, 16950.006, 16990.312, 17053.871, 17146.96 , 17271.934,
#        17502.38 , 17879.75 , 18491.93 , 19281.494, 20168.787, 20907.516,
#        21426.87 , 21452.018, 21552.697, 21822.172, 22137.38 , 22495.89 ,
#        22946.322, 23241.441, 23275.748, 23303.059, 23338.436, 23415.441,
#        23511.023, 23500.688, 23548.732, 23678.719, 23655.016, 23684.85 ,
#        23751.088, 23726.04 , 23574.322, 23503.287, 23340.271, 23090.854,
#        22843.78 , 22649.373, 22396.23 , 22263.97 , 22425.504, 22804.844,
#        23212.488, 23764.957, 24299.947, 24680.924, 24689.537, 24714.447,
#        24652.297], dtype=float32)

# %%
predicted_btc_test_concatenated = np.concatenate((predicted_btc_price_test_data, predicted_5_days_forecast_price_test_x))

predicted_btc_test_concatenated

predicted_btc_test_concatenated.shape
# Out:
# (60,)

# %%
plt.figure(figsize=(16,7))

plt.plot(predicted_btc_test_concatenated, 'r', marker='.', label='Predicted Test')

plt.plot(test_actual, marker='.', label='Actual Test')

plt.legend()

plt.show()
